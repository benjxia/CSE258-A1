# %%
import numpy as np
import pandas as pd

from sklearn import preprocessing
import torch
from torch import nn, optim
from torch.utils.data import Dataset, DataLoader
from transformers import AutoTokenizer, AutoModel

import random
from collections import defaultdict
from tqdm import tqdm
import gzip

import os


RANDOM_SEED = 0
random.seed(RANDOM_SEED)
np.random.seed(RANDOM_SEED)
torch.manual_seed(RANDOM_SEED)

# %%
def read_json(path):
    f: gzip.GzipFile = gzip.open(path)
    f.readline()
    for line in f:
        entry = eval(line)
        yield entry

data = []
for entry in read_json('train.json.gz'):
    data.append(entry)

df: pd.DataFrame = pd.DataFrame(data)

# %%
df.fillna(value=0, axis=1, inplace=True)
df['compensation'] = df['compensation'].map(lambda x : x if x == 0 else 1)
df[['early_access', 'compensation']] = df[['early_access', 'compensation']].astype(np.int32)

# %%
dftext = df.groupby('gameID')['text'].apply(' '.join).reset_index()
dftext.head()
# Out:
#       gameID                                               text
# 0  g00045539  The bard... He's a ♥♥♥♥♥♥♥. Selfish, egoistic,...
# 1  g00083675  Recomended. Painkiller eater simulator 10/10 t...
# 2  g00087199  yes. This game is fun because Slither.io is la...
# 3  g00102027  I don't even consider them games. What's the a...
# 4  g00125299  Was kinda expecting the House of the Dead, jus...

# %%
from nltk.stem import PorterStemmer,LancasterStemmer
import string
from sklearn import feature_extraction

counter = feature_extraction.text.CountVectorizer(min_df=0.01, max_df=0.5, stop_words='english', max_features=2000, ngram_range=(1, 2), binary=True)
wordcount = counter.fit_transform(dftext['text'])

# %%
"shooter" in counter.vocabulary_
# Out:
# True

# %%
i = 0
for x in counter.vocabulary_:
    print(x)
    i += 1
# Out:
# interested
# incredible
# alot
# creatures
# funny
# voice
# acting
# rpg
# classic
# buggy
# read
# visuals
# finished
# windows
# ago
# sad
# job
# effort
# interface
# listen
# following
# direction
# 360
# support
# generic
# controller
# unplayable
# entirely
# ends
# tale
# hidden
# gem
# friend
# sitting
# library
# awhile
# decided
# adventure
# view
# storyline
# close
# men
# brought
# wonderful
# spin
# tells
# face
# quick
# result
# shot
# playthrough
# wonder
# taken
# seriously
# heavily
# invested
# create
# special
# exactly
# fantasy
# genre
# creating
# entry
# uses
# magic
# personal
# gain
# stop
# evil
# course
# happens
# begins
# humor
# breaking
# wall
# everybody
# lines
# tech
# trees
# list
# abilities
# complaint
# occasional
# weapon
# upgrade
# fresh
# enjoying
# silly
# exploring
# setting
# fans
# haven
# heard
# hardly
# hold
# release
# nostalgia
# esque
# dark
# atmosphere
# relatively
# pleasant
# land
# encounter
# hilarious
# individual
# majority
# dated
# stories
# blast
# school
# today
# era
# complex
# expecting
# port
# console
# believe
# excellent
# laugh
# forever
# tree
# bigger
# weapons
# fighting
# monsters
# eventually
# girl
# live
# case
# shows
# effects
# shoot
# beautiful
# follow
# plot
# writing
# keeps
# balance
# slightly
# compared
# sword
# ability
# sit
# playable
# likes
# wants
# missed
# lives
# hear
# thanks
# happy
# typical
# picking
# beginning
# melee
# plays
# lovely
# included
# common
# smoothly
# master
# quests
# gamer
# puzzles
# changes
# everytime
# changing
# maps
# open
# eyes
# wide
# check
# expensive
# entertainment
# fairly
# linear
# grind
# cut
# wise
# charm
# repetitive
# boy
# grand
# light
# mood
# saves
# rating
# released
# says
# post
# box
# self
# familiar
# suppose
# particularly
# strong
# recommendation
# impossible
# soon
# begin
# rate
# chance
# giving
# attack
# effective
# corner
# resolution
# shooting
# odd
# places
# crashed
# progress
# attempt
# area
# finish
# older
# beaten
# path
# breaks
# terrible
# hot
# text
# cause
# manages
# bring
# elements
# adding
# hooked
# parts
# background
# history
# notice
# focus
# points
# badly
# walking
# lack
# info
# missing
# positive
# useless
# scenarios
# missions
# spent
# sadly
# negative
# ii
# tried
# grab
# didnt
# drive
# push
# saw
# im
# bother
# thats
# important
# voice acting
# years ago
# style game
# didn like
# just like
# great story
# story really
# bad game
# felt like
# game time
# lot fun
# fun playing
# haven played
# 10 fun
# fun little
# takes place
# game ll
# good fun
# game enjoy
# old school
# looking game
# game long
# game does
# games play
# lot game
# game doesn
# doesn feel
# good old
# play just
# adventure game
# little bit
# game love
# games played
# story just
# makes game
# gameplay fun
# game bad
# best games
# way game
# did enjoy
# old game
# main character
# love game
# parts game
# original game
# doesn make
# make sense
# want game
# isn really
# plays like
# simulator
# movie
# ive
# max
# stage
# ing
# brutal
# boss
# killing
# baby
# powerful
# scenes
# honestly
# reviews
# child
# depth
# mainly
# consists
# bullet
# welcome
# guns
# enemy
# head
# realistic
# obviously
# anymore
# honest
# aside
# 3rd
# shooter
# sets
# apart
# feeling
# remains
# till
# experienced
# video
# showing
# age
# collection
# went
# hey
# execution
# standards
# drawn
# hurt
# clunky
# novel
# wow
# taking
# early
# terms
# came
# considering
# couldn
# fix
# wouldn
# running
# needed
# holds
# runs
# modern
# patch
# forums
# machine
# days
# unlocked
# man
# doubt
# 13
# responsive
# storytelling
# started
# mechanic
# countless
# favorite
# xp
# wondering
# sounds
# strongly
# 12
# current
# cutscenes
# audio
# properly
# xbox
# somewhat
# physics
# systems
# send
# air
# black
# mention
# past
# download
# damn
# working
# custom
# walls
# waste
# form
# skip
# degree
# paper
# flying
# room
# return
# remember
# looked
# suddenly
# 15
# incredibly
# narrative
# unfortunately
# recent
# versions
# thankfully
# details
# truly
# masterpiece
# favourite
# shooters
# horrible
# rest
# pure
# gaming
# gold
# presentation
# ended
# childhood
# memories
# family
# cute
# wanna
# npc
# ai
# okay
# perspective
# gun
# setup
# cover
# excuse
# brilliant
# book
# hated
# weren
# frustrating
# combination
# badass
# forget
# sequel
# true
# medium
# lose
# solve
# problems
# introduced
# concept
# greatly
# ultimately
# loads
# mod
# thrown
# city
# harder
# 3d
# straight
# 2015
# year
# value
# health
# paced
# gamers
# surprise
# bits
# bullets
# dying
# whilst
# occasionally
# dialogue
# soundtrack
# possible
# aspect
# piece
# complain
# presented
# perfectly
# helped
# launch
# generation
# motion
# isnt
# crap
# penny
# combined
# graphic
# combine
# surprisingly
# trouble
# latest
# non
# lol
# edit
# score
# sucks
# happening
# dynamic
# deep
# filled
# murder
# called
# jokes
# situation
# helps
# development
# ending
# anti
# considered
# fight
# designed
# large
# selection
# state
# impact
# objects
# interaction
# provides
# immersion
# nicely
# fits
# ui
# interact
# actions
# accurate
# areas
# effect
# standing
# lucky
# manage
# destroy
# range
# figure
# damage
# multiple
# instantly
# bosses
# provide
# died
# trigger
# auto
# pro
# clear
# death
# options
# requires
# offers
# executed
# par
# driven
# cost
# mediocre
# fair
# totally
# locations
# mark
# suggest
# tone
# consider
# asked
# refund
# fixed
# rare
# movement
# packed
# fixes
# talking
# home
# killed
# group
# ammo
# depending
# shots
# replay
# usually
# care
# 60
# higher
# difficulties
# modes
# minute
# buying
# ask
# deal
# bundle
# include
# originally
# copy
# advanced
# computer
# mouse
# smooth
# fps
# textures
# available
# amazingly
# telling
# situations
# memorable
# superb
# surely
# install
# superior
# stronger
# stands
# ridiculous
# tedious
# broken
# newer
# settings
# stay
# ideas
# gotta
# stand
# 30
# worked
# encountered
# bugs
# required
# load
# previous
# feature
# loading
# saving
# quickly
# rarely
# tries
# told
# moment
# literally
# seconds
# added
# bunch
# ways
# number
# present
# quality
# regret
# exist
# capture
# movies
# personally
# hand
# putting
# edge
# protagonist
# hero
# twists
# happen
# search
# choose
# endless
# deserve
# rewarding
# engaging
# flaws
# leaves
# overly
# simplistic
# interactive
# rough
# late
# button
# track
# compelling
# engine
# unlike
# plenty
# atmospheric
# additional
# complicated
# compare
# saying
# word
# improved
# catch
# skills
# realized
# beautifully
# sections
# albeit
# blood
# dead
# lets
# hopefully
# drop
# regular
# guy
# luck
# human
# count
# sorry
# paid
# longer
# worst
# jumping
# game best
# game awesome
# just feels
# feels like
# person shooter
# solid game
# game ve
# people game
# video games
# games ve
# ve got
# just doesn
# gameplay mechanics
# game came
# like did
# game run
# people like
# want play
# art style
# game runs
# way better
# time time
# action game
# rating 10
# 10 great
# fun play
# worth playing
# story good
# highly recommend
# buy game
# game played
# played game
# game don
# don mind
# waste money
# just play
# game graphics
# review game
# game looks
# looks great
# time game
# game released
# highly recommended
# great gameplay
# finish game
# game didn
# just game
# game felt
# good story
# really cool
# version game
# game years
# end game
# ve seen
# single player
# just good
# play time
# able play
# times game
# game amazing
# fast paced
# interesting story
# definitely worth
# don expect
# good graphics
# game worth
# don like
# game actually
# really good
# make game
# game look
# game story
# rest game
# game easy
# sound effects
# overall game
# game offers
# looks like
# game looking
# said game
# score 10
# fun just
# good way
# video game
# game think
# think game
# games time
# game sale
# level design
# replay value
# multiple times
# hours game
# worth buying
# year old
# game better
# don bother
# stay away
# 30 minutes
# game works
# worth money
# don let
# time played
# bought game
# game buy
# game feel
# game mechanics
# game gameplay
# game based
# really nice
# good thing
# thing game
# like just
# play good
# god
# awsome
# killer
# grow
# giant
# drops
# success
# worse
# alright
# ground
# larger
# survival
# forth
# yeah
# addictive
# escape
# touch
# leave
# biggest
# rip
# items
# opinion
# 11
# spending
# losing
# kid
# starts
# kids
# addicting
# user
# lag
# server
# suck
# reach
# battles
# mass
# mistake
# tiny
# internet
# recomend
# hate
# exact
# clone
# step
# guide
# cash
# dream
# finally
# extreme
# boxes
# avoid
# travel
# meet
# eat
# steal
# food
# devs
# vs
# key
# great time
# game breaking
# pretty fun
# good bad
# game free
# really fun
# game pretty
# game know
# 11 10
# don play
# don need
# different game
# game modes
# say game
# better game
# game 10
# like playing
# appeal
# actual
# matter
# refreshing
# stats
# active
# bucks
# flash
# offline
# require
# strategy
# features
# clicking
# despite
# kinda
# given
# tutorial
# gone
# loved
# loot
# grinding
# gonna
# write
# achievements
# lacks
# basic
# powers
# meh
# normal
# costs
# 99
# luckily
# achievement
# dumb
# defeat
# line
# total
# prepared
# power
# final
# clean
# dev
# update
# 25
# constantly
# hitting
# 16
# known
# ultimate
# ran
# bloody
# wont
# xd
# general
# nearly
# hands
# break
# discover
# dies
# unlock
# choice
# team
# knowing
# created
# impressive
# follows
# stages
# survive
# fights
# click
# attacking
# 80
# discount
# sales
# agree
# local
# continue
# titles
# expectations
# casual
# adds
# element
# charming
# similar
# pay
# mess
# artwork
# shame
# making game
# game bit
# better games
# just want
# free game
# don really
# game steam
# play like
# overall 10
# simple game
# free play
# waste time
# real life
# run game
# game yes
# got game
# long time
# time playing
# nice graphics
# boss fights
# don recommend
# game far
# house
# arcade
# words
# tight
# budget
# stuck
# glitches
# mini
# exciting
# theme
# suffers
# poor
# length
# optional
# explain
# entertaining
# bored
# em
# normally
# wanting
# learn
# hardcore
# coop
# worry
# keyboard
# issue
# random
# crashes
# strange
# event
# sort
# dlc
# watch
# online
# trash
# freaking
# faster
# test
# object
# kills
# zombies
# miss
# bonus
# talk
# moves
# popular
# pop
# earn
# op
# contains
# appear
# awful
# upgrades
# particular
# option
# press
# trust
# tired
# packs
# workshop
# rules
# progression
# unlocking
# highest
# months
# changed
# updated
# imagine
# fully
# crazy
# addition
# company
# weird
# likely
# order
# learning
# barely
# multiplayer
# function
# thank
# section
# randomly
# conclusion
# cheap
# 50
# 75
# average
# worthy
# purpose
# recommending
# tons
# split
# coming
# improve
# speed
# difference
# currently
# easier
# anyways
# surprised
# challenges
# shop
# rage
# finishing
# opening
# brain
# base
# joke
# replayability
# loving
# outside
# knew
# horror
# 14
# warning
# cards
# practice
# franchise
# possibly
# complaints
# gave
# dude
# white
# sick
# balls
# ruined
# broke
# package
# share
# war
# formula
# project
# failed
# access
# stopped
# paying
# attention
# mission
# dollar
# achieve
# intended
# keeping
# switch
# menu
# meant
# extra
# slowly
# scary
# havent
# experiences
# crappy
# crashing
# entire
# spot
# placed
# completing
# smart
# hasn
# gotten
# bar
# rock
# turning
# models
# minimal
# visually
# stunning
# gamepad
# ton
# busy
# technical
# fall
# market
# intuitive
# note
# lacking
# clever
# standard
# falls
# stupid
# btw
# includes
# increase
# speak
# class
# middle
# minor
# menus
# allowed
# purchase
# watching
# reading
# proper
# management
# understand
# managed
# themes
# reality
# regardless
# graphical
# bug
# slight
# closer
# lost
# combo
# directly
# mixed
# plus
# seeing
# scene
# camera
# admit
# ride
# massive
# dislike
# files
# ingame
# aaa
# enjoyment
# inside
# pain
# atleast
# definately
# secrets
# ups
# disappointed
# win
# aesthetic
# plan
# leaving
# taste
# pacing
# utterly
# insane
# glad
# garbage
# retro
# reccomend
# pressing
# reasonable
# leads
# bland
# infinite
# curve
# aim
# aiming
# confused
# skill
# water
# alive
# awesome game
# great fun
# graphics good
# buying game
# just fun
# game takes
# quite fun
# definitely recommend
# really enjoy
# ll just
# great graphics
# favorite games
# games don
# games just
# don buy
# game perfect
# type game
# short game
# 10 best
# problem game
# game feels
# gets boring
# doesn work
# really want
# point game
# game makes
# just right
# like good
# decent game
# lots fun
# don think
# fun good
# doesn really
# like play
# don know
# gameplay game
# game definitely
# perfect game
# game gets
# quite bit
# best game
# overall great
# game different
# game got
# story game
# ll probably
# game did
# lot people
# game short
# game interesting
# bad thing
# game probably
# little game
# loved game
# reccomend game
# game absolutely
# learning curve
# enjoy game
# know game
# match
# board
# charge
# collect
# resources
# doors
# equipment
# goal
# eye
# involved
# factor
# fail
# turned
# puzzle
# quest
# purchasing
# mobile
# mix
# explore
# named
# locked
# door
# deeper
# selling
# freedom
# beating
# objectives
# double
# matches
# reminds
# initially
# videos
# pass
# dollars
# brings
# core
# unlocks
# thoroughly
# build
# asking
# attacks
# monster
# leveling
# armor
# keys
# forward
# trading
# pixel
# plain
# nope
# indie
# instance
# useful
# essentially
# satisfying
# appears
# defense
# various
# task
# automatically
# youtube
# willing
# platforming
# counter
# journey
# listening
# doesnt
# tools
# sweet
# destroyed
# choices
# mentioned
# wasted
# deliver
# balanced
# limit
# lower
# fell
# joy
# moving
# creates
# usual
# careful
# tough
# fit
# exploration
# rewards
# quit
# explained
# crash
# sell
# lame
# obvious
# hits
# buildings
# platformer
# semi
# twist
# specific
# types
# purchased
# allows
# cases
# rush
# sake
# epic
# correct
# expected
# example
# cast
# future
# game quite
# game try
# game enjoyable
# puzzle game
# just make
# totally worth
# liked game
# played hours
# spend time
# don care
# really like
# 10 hours
# trading cards
# really really
# started playing
# game simple
# beat game
# hours fun
# 10 good
# finished game
# good time
# game little
# game hard
# games like
# look like
# indie game
# fun like
# visual
# happened
# numerous
# decisions
# clearly
# decision
# handle
# written
# forced
# apparently
# confusing
# ship
# moments
# finding
# crafted
# demo
# size
# space
# completion
# certainly
# layout
# ready
# tend
# reasons
# secret
# generally
# limited
# genuinely
# results
# immersive
# focused
# traditional
# model
# repeat
# tag
# suffer
# walk
# dozen
# description
# page
# ruin
# heart
# nature
# direct
# tl
# dr
# continues
# picked
# completed
# night
# pace
# developed
# thinking
# jump
# cross
# information
# sorts
# ones
# near
# thoughts
# couple hours
# game start
# getting game
# looking forward
# game price
# really liked
# really need
# game highly
# worth price
# enjoyable game
# game way
# tl dr
# really enjoyed
# enjoyed game
# interesting game
# good good
# 10 game
# game recommend
# rooms
# trial
# error
# instant
# blue
# green
# supposed
# act
# mystery
# optimization
# intense
# platform
# approach
# remove
# polished
# fly
# star
# wtf
# block
# turns
# loose
# building
# trailer
# built
# product
# angry
# select
# colors
# process
# defend
# strategic
# tricky
# affect
# ugly
# chose
# really game
# price tag
# aspect game
# game people
# just don
# like games
# pretty cool
# developer
# english
# reward
# game kind
# time just
# 2d
# premise
# guys
# tactics
# throw
# restart
# date
# varied
# puts
# frustrated
# kick
# outstanding
# verdict
# gud
# car
# meat
# hardest
# colorful
# holy
# draw
# including
# gg
# tracks
# chapter
# floor
# respect
# fluid
# favor
# frustration
# decide
# appreciate
# learned
# aware
# events
# immediately
# promise
# vast
# stealth
# carry
# target
# sight
# body
# numbers
# dull
# heck
# round
# offer
# ahead
# earlier
# designs
# shallow
# environment
# weeks
# 2nd
# ed
# souls
# frequently
# week
# greatest
# imo
# deserves
# thumbs
# spoilers
# lead
# deaths
# living
# loves
# insanely
# mad
# develop
# potential
# sheer
# flow
# sold
# tho
# bright
# 2016
# tactical
# checking
# recently
# spawn
# lazy
# gorgeous
# seemingly
# pull
# impression
# meaning
# community
# patience
# notch
# installed
# forcing
# throwing
# zero
# mins
# unfair
# theres
# major
# updates
# necessary
# source
# location
# questions
# excited
# friendly
# diverse
# red
# hang
# inventory
# shouldn
# screens
# pack
# twice
# stars
# detailed
# tasks
# good gameplay
# makes feel
# game extremely
# try game
# story line
# game want
# game starts
# nice game
# game overall
# game going
# probably best
# things game
# later game
# fun gameplay
# game isn
# game basically
# makes sense
# make feel
# amazing game
# complete game
# game lot
# buy sale
# really hard
# game cool
# game need
# game make
# really just
# main game
# excellent game
# worth time
# kind game
# really great
# just buy
# things like
# play games
# 10 play
# game right
# fantastic game
# game hours
# game real
# looks good
# game series
# cool game
# game lots
# relaxing
# king
# animations
# ish
# prefer
# paths
# planning
# kept
# 1st
# objective
# downside
# card
# production
# pre
# poorly
# games game
# game bought
# start game
# actually pretty
# price game
# game needs
# game nice
# absolute
# mods
# neat
# research
# battle
# allow
# rich
# account
# store
# hoping
# 90
# game gives
# game especially
# isn bad
# stop playing
# early access
# game won
# make sure
# 40
# starting
# heavy
# performance
# mistakes
# item
# realize
# saved
# comparison
# matters
# town
# handful
# playtime
# universe
# hunting
# entire game
# good job
# game world
# hours gameplay
# dropped
# 2017
# sim
# 2014
# gear
# styles
# force
# lore
# fails
# earth
# stick
# campaign
# creative
# environments
# glitch
# constant
# roll
# scale
# advance
# optimized
# ignore
# figured
# chore
# disappointing
# watched
# knows
# personality
# position
# advantage
# bothered
# hundreds
# forces
# screw
# gripe
# ruins
# sleep
# graphically
# default
# leading
# improvement
# weak
# aspects
# army
# connection
# npcs
# pointless
# singleplayer
# greater
# implemented
# window
# period
# solving
# inspired
# expansion
# soul
# speaking
# mid
# impressed
# unable
# collecting
# pieces
# dodge
# tank
# surface
# opportunity
# blow
# forgot
# scenery
# appealing
# wait sale
# didn really
# don feel
# great job
# 10 minutes
# game year
# new game
# negative reviews
# open world
# don want
# game playing
# game plays
# money game
# game new
# story great
# game say
# really recommend
# game fantastic
# didn know
# graphics great
# experience game
# game design
# lot time
# dont know
# really bad
# game dont
# story interesting
# game simply
# gameplay 10
# safe
# helpful
# worlds
# classes
# unfinished
# waiting
# memory
# color
# polish
# customization
# solo
# provided
# falling
# buttons
# exit
# race
# question
# screenshots
# removed
# feel game
# beta
# crafting
# animation
# drag
# enter
# party
# servers
# sandbox
# code
# quite good
# play friends
# game sure
# graphics game
# lighting
# exception
# fear
# solution
# allowing
# flat
# strike
# distance
# holding
# role
# risk
# join
# improvements
# technically
# field
# humble
# patches
# ages
# game unique
# noticed
# searching
# related
# amounts
# caught
# intriguing
# games really
# 20 minutes
# hide
# multi
# sound design
# time play
# young
# initial
# awkward
# like really
# beautiful game
# people play
# ps
# hack
# fun time
# steep
# winning
# laptop
# terribly
# metal
# builds
# kinds
# main story
# stuff like
# 70
# edition
# suit
# fault
# frame
# customize
# answer
# good idea
# pretty decent
# craft
# previously
# hours playing
# connect
# boost
# whatsoever
# meets
# delivers
# smaller

# %%
from sklearn.decomposition import LatentDirichletAllocation

LDA = LatentDirichletAllocation(n_components=20, random_state=RANDOM_SEED)
reps = LDA.fit_transform(wordcount)

# %%
df['gameID'].value_counts()[dftext.iloc[0]['gameID']]
# Out:
# 26

# %%
dftext.iloc[0]['text']
# Out:
# 'The bard... He\'s a ♥♥♥♥♥♥♥. Selfish, egoistic, zynic, mostly interested in cleavage, maybe also beer. The game pulls out an incredible amount of humour. And combat goes alot about summoning creatures. Pros:\n+ funny (!!)\n+ voice acting\n+ songs\n+ RPG classic\nCons:\n- buggy (!!!) Linux users read below\n- outdated visuals\nI finished it on Windows many many years ago and, hell, it was fun! It\'s sad whoever did the job of porting it to Linux didn\'t put much effort into it.\nInterface often doesn\'t listen, in-game map stops following player\'s direction after 360 turn, support for generic controller (anything but xbox360) is only partial (and can\'t remap), abusive particle system sometimes renders game unplayable (if unlucky, one torch on the map will freeze the game entirely). ...and thus ends the Bard\'s Tale.  This was a GREAT hidden gem, which I think a friend sent me.  In anycase it\'s been sitting in my game library for awhile so decided to play it.  It\'s a top down diablo adventure style game.  The game is decent and challenging and perhaps the only thing I didn\'t like about it was the top down view, it just took awhile to get use to.  The storyline and game play is very close to a Monty Python, Princess Bride, and Robin Hood Men in Tights.  It\'s just full of great derp.  The narrator, by Tony Jay brought the game to life.  The voice acting was wonderful and it was hard to put down.\nJust like Bard\'s that spin up a great story, The Bard\'s Tale tells a great story and it was really enjoyable..  I recommend it to anyone that needs a good smile brought to their face. An ammusing narative, but it can get old quick when that\'s all to save you from dodgy combat mechanics that result in you getting one shot at the same point every time, miles from a save point.\nIt\'s a one-playthrough wonder, something to not be taken too seriously, and not too heavily invested in. The creators of The Bard\'s Tale (2004) said that they wanted to create something special and that\'s exactly what The Bard\'s Tale is. The game is something of a fractured fairy-tale and focuses more on poking fun at the fantasy/adventure/rpg genre than creating just another entry in the sea of fantasy rpgs. You play as The Bard (voiced by Cary Elwes) who is more interested in women, wine, and coin than adventuring. He uses his magic for his own personal gain. Being pulled into an adventure to save a damsel in distress and stop an evil sorcerer was the last thing on his mind. So of course... that\'s what happens. And so our story begins... The game serves more as a vessel for crude humor, snarky remarks, and breaking the 4th wall. This may not be for everybody but certain lines are bound to make you chuckle. As for the gameplay, it\'s not bad at all. The game is solid, simple, and different from most fantasy games. Rather than having convoluted tech trees and a long list of abilities, The Bard\'s Tale focuses on simple top-down combat and using summons. My main complaint is the repetitiveness of the combat. Some segments felt like they were there to pad the game time and give you more experience but gaining new summons and the occasional weapon upgrade help to keep things a bit more fresh. Overall, I had a lot of fun playing this game and enjoying some sharp wit and silly songs while exploring a unique Scottish fantasy setting.\nFor those who are fans of the original games, the original Bard\'s Tale trilogy from the 80s now comes with this game. I haven\'t played them but I\'ve heard that The Bard\'s Tale (2004) hardly resembles the original games. With 4 games in 1, this may be enough to hold you until the release of the newly kickstarted The Bard\'s Tale IV.\n7/10 A fun little romp in nostalgia, The Bard\'s Tale is a Diablo-esque action RPG that, instead of demons and a dark atmosphere, takes place in a relatively pleasant land where humor abounds.  As you venture through the game you\'ll encounter all manner of singing goblins, hilarious misundersta ...

# %%
reps[0]
# Out:
# array([1.61812302e-04, 1.61812301e-04, 1.61812302e-04, 3.90664928e-01,
#        1.61812302e-04, 1.61812302e-04, 1.61812302e-04, 1.61812302e-04,
#        1.61812302e-04, 2.42927091e-02, 1.61812299e-04, 1.61812302e-04,
#        1.54874787e-01, 1.61812301e-04, 1.18368151e-01, 1.61812302e-04,
#        3.09372240e-01, 1.61812300e-04, 1.61812301e-04, 1.61812300e-04])

# %%
def display_topics(model, feature_names, no_top_words):
    for topic_idx, topic in enumerate(model.components_):
        print("Topic %d:" % (topic_idx))
        print (" ".join([feature_names[i]
                        for i in topic.argsort()[:-no_top_words - 1:-1]]))

no_top_words = 30
display_topics(LDA, counter.get_feature_names_out(), no_top_words)
# Out:
# Topic 0:
# grind free play pay grinding items earn win spending quest shop quests unlock cash mobile item paying casual waste lose gold account click gain game free waste time rewards higher skills addictive download
# Topic 1:
# bugs devs update updates potential fix ing im community access early access multiplayer early simulator thats lag buggy waste alot buying reviews terrible unplayable year horrible fps worst tried state running
# Topic 2:
# expansion multiplayer previous released ai features campaign franchise mods release improved compared community fans available maps mod favorite added single player base opinion improvements dlc classic original game came ii online bugs
# Topic 3:
# voice acting voice acting weapons enemy weapon terrible plot fight worst storyline problems missions worse bugs poor mission mouse open awful clunky fps cutscenes shooter running gun came cheap special finish
# Topic 4:
# cover gun guns shooting shooter single player person shooter exciting bullet campaign mission badass fps killing good graphics great graphics shooters aim console weapon shoot intense average realistic good story taking dlc movie satisfying history
# Topic 5:
# simulator man funny guy reading 11 laugh read lol 11 10 ending video don know game 10 spent understand honestly humor watch minute seriously weird achievements value cute reviews saw believe okay pay
# Topic 6:
# game story story good good story storyline plot dialogue story really cast stories voice acting great story main story acting engaging voice written compelling outstanding development story great depth complex form writing twists highly recommend beautiful excellent story game artwork
# Topic 7:
# controller soundtrack platformer boss 2d keyboard platforming bosses jump retro frustrating classic arcade unlock button school jumping platform extra tight score death final stages attack collect enemy fights art style level design
# Topic 8:
# strategy learning strategic learning curve curve building management build depth quickly addictive learn limited tutorial complex lose resources campaign replayability manage possible basic win genre number enemy tactical types mission random
# Topic 9:
# rpg attack stats enemy abilities battle quests strategy loot build quest attacks fight battles equipment upgrade genre random damage cards items fantasy skills fighting grind trading leveling monsters repetitive points
# Topic 10:
# death kept demo ve seen seconds reach short game game did man went literally beautiful paper rpg fps cover piece cards game basically really recommend ending don recommend cheap special spent bored weird button standards video
# Topic 11:
# puzzle puzzle game puzzles indie concept achievements relaxing little game casual finish frustrating solve progress goal bundle fun little cheap achievement completed wouldn cute indie game order mechanic basic quick fairly sounds repetitive pass
# Topic 12:
# adventure adventure game puzzles click voice acting plot ending voice acting atmosphere dialogue solve genre writing scenes written setting quality puzzle items mystery stuck excellent beautiful soundtrack good story storyline read visuals loved
# Topic 13:
# modes multiplayer online matches match game modes maps community team win ai servers single player vs support love game choose plays options shot paced potential speed customization dead tutorial fps fun play strategy battle
# Topic 14:
# exploration explore exploring atmosphere areas dark area jump places death environments elements secrets walk walking encounter playthrough environment feeling direction atmospheric entirely open linear appreciate light progress gorgeous clear wonderful
# Topic 15:
# op multiplayer online coop weapons single player play friends solo fun play weapon really fun enemy shooter blast killing modes skill friend choose health classes unlock support fast paced dead quick paced addictive special community
# Topic 16:
# favorite age ago classic memories today modern favourite older kid remember loved played game years ago childhood love game systems dated amazing game school universe games time favorite games greatest best games incredible game best best game haven created
# Topic 17:
# costs manages path handle earn impression frustration heart personal final provide regardless majority text ways complaint narrative giving sweet cute possible self art style wants storyline visual achievements surprisingly lead trust
# Topic 18:
# speed platformer soundtrack stage level design worst developer platforming fun play boy arcade note drop check length ugly meat types close fps frustrating poorly don care jump controller online puzzle tedious concept addicting
# Topic 19:
# repetitive sort understand effort points puzzle sequel cards game 10 hey 10 game score learn quickly general order seeing plenty easier limit reasons collect creates puzzles best game flash fps edition tried worst

# %%
mat.shape
# Out:
# (174999, 14301)

# %%
df['gameID'].value_counts()
# Out:
# g10773791    1092
# g05463839     943
# g75228197     897
# g40499587     794
# g11862712     746
#              ...
# g17749950       9
# g13018310       9
# g85968616       9
# g61046982       9
# g67585399       8
# Name: gameID, Length: 2437, dtype: int64

# %%
tmp = df.groupby('gameID')['text'].
